# %%
import numpy
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('train.csv')
dataset.fillna(dataset.mean(axis=0), inplace=True)
dataset.head()
# Out:
#    Id  Feature_1  Feature_2  ...  Ret_PlusTwo  Weight_Intraday  Weight_Daily
# 0   1    3.59025  -0.117558  ...     0.028846     1.251508e+06  1.564385e+06
# 1   2    3.59025  -0.117558  ...    -0.010253     1.733950e+06  2.167438e+06
# 2   3    3.59025  -0.696727  ...     0.015711     1.529197e+06  1.911497e+06
# 3   4    3.59025  -0.694350  ...    -0.002190     1.711569e+06  2.139462e+06
# 4   5    6.00000  -1.736489  ...    -0.026552     1.267270e+06  1.584088e+06
#
# [5 rows x 211 columns]

# %%
#Splitting the dataset into X and Y, ie input and output values
X_original = dataset.iloc[:,0:27]
Y_original = dataset.iloc[:,85]

# %%
X_original.head()
# Out:
#    Id  Feature_1  Feature_2  ...  Feature_24  Feature_25  Ret_MinusTwo
# 0   1    3.59025  -0.117558  ...   -1.209290   -0.329675      0.055275
# 1   2    3.59025  -0.117558  ...    0.953424   -0.709462      0.009748
# 2   3    3.59025  -0.696727  ...   -1.798090   -1.019370      0.003077
# 3   4    3.59025  -0.694350  ...   -1.788725   -0.329675      0.000984
# 4   5    6.00000  -1.736489  ...   -5.993092    3.219820     -0.018224
#
# [5 rows x 27 columns]

# %%
X_original.shape
# Out:
# (40000, 27)

# %%
Y_original.head()
# Out:
# 0   -0.001152
# 1   -0.000180
# 2   -0.000284
# 3   -0.000076
# 4    0.000020
# Name: Ret_59, dtype: float64

# %%
Y_original.shape
# Out:
# (40000,)

# %%
#Normalizing X_original to X_scaled
normalize_X = MinMaxScaler()
normalize_X.fit(X_original)
X_scaled=normalize_X.transform(X_original)

# %%
#Model 1: Sequential
model = Sequential()
model.add(Dense(12, input_dim=27, kernel_initializer='normal'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 12)                336
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])

# %%
result = model.fit(X_scaled, Y_original,epochs=50, batch_size=10)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 40000/40000 [==============================] - 4s 97us/step - loss: 2.7156e-05 - mean_squared_error: 2.7156e-05 - mean_absolute_error: 0.0021
# Epoch 2/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 2.0570e-06 - mean_squared_error: 2.0570e-06 - mean_absolute_error: 0.0010
# Epoch 3/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.6523e-06 - mean_squared_error: 1.6523e-06 - mean_absolute_error: 9.1653e-04
# Epoch 4/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.7012e-06 - mean_squared_error: 1.7012e-06 - mean_absolute_error: 8.9021e-04
# Epoch 5/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.6529e-06 - mean_squared_error: 1.6529e-06 - mean_absolute_error: 8.9587e-04
# Epoch 6/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.6528e-06 - mean_squared_error: 1.6528e-06 - mean_absolute_error: 8.8696e-04
# Epoch 7/50
# 40000/40000 [==============================] - 4s 100us/step - loss: 1.4701e-06 - mean_squared_error: 1.4701e-06 - mean_absolute_error: 8.2725e-04
# Epoch 8/50
# 40000/40000 [==============================] - 4s 102us/step - loss: 1.5167e-06 - mean_squared_error: 1.5167e-06 - mean_absolute_error: 8.4745e-04
# Epoch 9/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 2.1581e-06 - mean_squared_error: 2.1581e-06 - mean_absolute_error: 9.7916e-04
# Epoch 10/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.4236e-06 - mean_squared_error: 1.4236e-06 - mean_absolute_error: 8.1862e-04
# Epoch 11/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.7193e-06 - mean_squared_error: 1.7193e-06 - mean_absolute_error: 9.0038e-04
# Epoch 12/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.4212e-06 - mean_squared_error: 1.4212e-06 - mean_absolute_error: 8.1630e-04
# Epoch 13/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.7133e-06 - mean_squared_error: 1.7133e-06 - mean_absolute_error: 8.5058e-04
# Epoch 14/50
# 40000/40000 [==============================] - 4s 98us/step - loss: 1.4869e-06 - mean_squared_error: 1.4869e-06 - mean_absolute_error: 8.4651e-04
# Epoch 15/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.4505e-06 - mean_squared_error: 1.4505e-06 - mean_absolute_error: 8.2396e-04
# Epoch 16/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.5288e-06 - mean_squared_error: 1.5288e-06 - mean_absolute_error: 8.4267e-04
# Epoch 17/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 2.2859e-06 - mean_squared_error: 2.2859e-06 - mean_absolute_error: 9.1011e-04
# Epoch 18/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3465e-06 - mean_squared_error: 1.3465e-06 - mean_absolute_error: 7.8938e-04
# Epoch 19/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.6218e-06 - mean_squared_error: 1.6218e-06 - mean_absolute_error: 8.6570e-04
# Epoch 20/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 2.0820e-06 - mean_squared_error: 2.0820e-06 - mean_absolute_error: 9.1210e-04
# Epoch 21/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3459e-06 - mean_squared_error: 1.3459e-06 - mean_absolute_error: 7.9443e-04
# Epoch 22/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.6039e-06 - mean_squared_error: 1.6039e-06 - mean_absolute_error: 8.5806e-04
# Epoch 23/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.5698e-06 - mean_squared_error: 1.5698e-06 - mean_absolute_error: 8.2402e-04
# Epoch 24/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.6048e-06 - mean_squared_error: 1.6048e-06 - mean_absolute_error: 8.6870e-04
# Epoch 25/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3537e-06 - mean_squared_error: 1.3537e-06 - mean_absolute_error: 7.8287e-04
# Epoch 26/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3443e-06 - mean_squared_error: 1.3443e-06 - mean_absolute_error: 7.6899e-04
# Epoch 27/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.4608e-06 - mean_squared_error: 1.4608e-06 - mean_absolute_error: 8.1140e-04
# Epoch 28/50
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.3830e-06 - mean_squared_error: 1.3830e-06 - mean_absolute_error: 7.8610e-04
# Epoch 29/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.4300e-06 - mean_squared_error: 1.4300e-06 - mean_absolute_error: 8.0528e-04
# Epoch 30/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.6538e-06 - mean_squared_error: 1.6538e-06 - mean_absolute_error: 8.6235e-04
# Epoch 31/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.2739e-06 - mean_squared_error: 1.2739e-06 - mean_absolute_error: 7.6227e-04
# Epoch 32/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3873e-06 - mean_squared_error: 1.3873e-06 - mean_absolute_error: 7.7951e-04
# Epoch 33/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.4070e-06 - mean_squared_error: 1.4070e-06 - mean_absolute_error: 7.6810e-04
# Epoch 34/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.4568e-06 - mean_squared_error: 1.4568e-06 - mean_absolute_error: 8.1687e-04
# Epoch 35/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3033e-06 - mean_squared_error: 1.3033e-06 - mean_absolute_error: 7.5714e-04
# Epoch 36/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.5137e-06 - mean_squared_error: 1.5137e-06 - mean_absolute_error: 8.4013e-04
# Epoch 37/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.2749e-06 - mean_squared_error: 1.2749e-06 - mean_absolute_error: 7.6129e-04
# Epoch 38/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.4837e-06 - mean_squared_error: 1.4837e-06 - mean_absolute_error: 8.0802e-04
# Epoch 39/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.2562e-06 - mean_squared_error: 1.2562e-06 - mean_absolute_error: 7.4436e-04
# Epoch 40/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 2.5232e-06 - mean_squared_error: 2.5232e-06 - mean_absolute_error: 7.9383e-04
# Epoch 41/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 9.9283e-07 - mean_squared_error: 9.9283e-07 - mean_absolute_error: 6.0379e-04
# Epoch 42/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.0302e-06 - mean_squared_error: 1.0302e-06 - mean_absolute_error: 6.2919e-04
# Epoch 43/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.0180e-06 - mean_squared_error: 1.0180e-06 - mean_absolute_error: 6.2340e-04
# Epoch 44/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.0168e-06 - mean_squared_error: 1.0168e-06 - mean_absolute_error: 6.2228e-04
# Epoch 45/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.0149e-06 - mean_squared_error: 1.0149e-06 - mean_absolute_error: 6.1981e-04
# Epoch 46/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.0235e-06 - mean_squared_error: 1.0235e-06 - mean_absolute_error: 6.2491e-04
# Epoch 47/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.0105e-06 - mean_squared_error: 1.0105e-06 - mean_absolute_error: 6.2094e-04
# Epoch 48/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.0124e-06 - mean_squared_error: 1.0124e-06 - mean_absolute_error: 6.1624e-04
# Epoch 49/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.0201e-06 - mean_squared_error: 1.0201e-06 - mean_absolute_error: 6.2410e-04
# Epoch 50/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.0270e-06 - mean_squared_error: 1.0270e-06 - mean_absolute_error: 6.2923e-04

# %%
plt.plot(result.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
testdata = pd.read_csv('test_2.csv')
testdata.fillna(testdata.mean(axis=0), inplace=True)

# %%
#Splitting the test data and normalizing
X_test = testdata.iloc[:,0:27] 
Y_test = testdata.iloc[:,85]

normalize_X.fit(X_test)
X_scaled_test =normalize_X.transform(X_test)

# %%
Ynew = model.predict(X_scaled_test)

# %%
X_scaled_test
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 6.37679216e-01, ...,
#         7.83682410e-01, 2.48052986e-01, 4.64848302e-01],
#        [1.07627566e-05, 2.71755589e-01, 4.41862324e-01, ...,
#         7.13381825e-01, 1.99226110e-01, 4.89662857e-01],
#        [2.15255131e-05, 2.71755589e-01, 3.78082324e-01, ...,
#         6.88014797e-01, 2.66320968e-01, 4.41931083e-01],
#        ...,
#        [9.99978474e-01, 2.71755589e-01, 4.37891431e-01, ...,
#         8.29903162e-01, 2.07895939e-01, 4.88644410e-01],
#        [9.99989237e-01, 1.11111111e-01, 4.41862324e-01, ...,
#         6.89469275e-01, 8.98537291e-02, 4.83721385e-01],
#        [1.00000000e+00, 2.71755589e-01, 5.07609473e-01, ...,
#         4.98240048e-01, 1.07168052e-01, 4.48951065e-01]])

# %%
X_scaled_test.shape
# Out:
# (92914, 27)

# %%
Ynew
# Out:
# array([[-0.00034478],
#        [-0.00034478],
#        [-0.00034478],
#        ...,
#        [-0.00034478],
#        [-0.00034478],
#        [-0.00034478]], dtype=float32)

# %%
Ynew.shape
# Out:
# (92914, 1)

# %%
plt.plot(Ynew)
plt.plot(Y_test)
plt.title('model loss')
plt.ylabel('Value')
plt.xlabel('Data Points')
plt.legend(['Predicted','Real'], loc='upper left')
plt.show()
Ynew
# Out:
# array([[-0.00034478],
#        [-0.00034478],
#        [-0.00034478],
#        ...,
#        [-0.00034478],
#        [-0.00034478],
#        [-0.00034478]], dtype=float32)

# %%
#Model 2:LSTM with the original data
X_scaled = numpy.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()

model.add(LSTM(units = 10, return_sequences = True, input_shape = (X_scaled.shape[1], 1)))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10))
model.add(Dropout(0.025))

model.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error' ,metrics = ['accuracy'])

# %%
model.fit(X_scaled, Y_original, epochs = 5, batch_size = 16)
# Out:
# Epoch 1/5
# 40000/40000 [==============================] - 125s 3ms/step - loss: 3.9338e-06 - acc: 0.0060
# Epoch 2/5
# 40000/40000 [==============================] - 121s 3ms/step - loss: 1.1886e-06 - acc: 0.0060
# Epoch 3/5
# 40000/40000 [==============================] - 119s 3ms/step - loss: 1.0941e-06 - acc: 0.0060
# Epoch 4/5
# 40000/40000 [==============================] - 124s 3ms/step - loss: 1.0623e-06 - acc: 0.0060
# Epoch 5/5
# 40000/40000 [==============================] - 119s 3ms/step - loss: 1.0156e-06 - acc: 0.0060
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-da961efc4c41> in <module>()
#       1 model.fit(X_scaled, Y_original, epochs = 5, batch_size = 16)
#       2
# ----> 3 X_scaled_test = model.reshape(X_scaled_test, (X_scaled_test.shape[0], X_scaled_test.shape[1], 1))
#       4 predicted_stock_price = model.predict(X_scaled_test)
#
# AttributeError: 'Sequential' object has no attribute 'reshape'

# %%
X_scaled_test = numpy.reshape(X_scaled_test, (X_scaled_test.shape[0], X_scaled_test.shape[1], 1))
predicted_stock_price = model.predict(X_scaled_test)

# %%
plt.plot(predicted_stock_price)
plt.plot(Y_test)
plt.title('model loss')
plt.ylabel('Value')
plt.xlabel('Data Points')
plt.legend(['Predicted','Real'], loc='upper left')
plt.show()

# %%
#Model 3 uses modtified data: returns relative to day 1 instead of thr previous day

#Modifying one column:
dataframe = pd.DataFrame({"Ret_2": numpy.random.randn(898), "Ret_3": numpy.random.randn(898)}) 
dataframe['Ret_3new'] = dataframe['Ret_2'] + dataframe['Ret_3']
dataframe.head()
# Out:
#       Ret_2     Ret_3  Ret_3new
# 0  0.239972  0.684274  0.924247
# 1  2.197689  0.265870  2.463558
# 2 -1.935293  0.268622 -1.666671
# 3  0.230908  0.271227  0.502135
# 4 -0.779542  0.496503 -0.283039

# %%
cols = dataset.columns
index = cols[27:205]
index #the columns that are used TO modify
# Out:
# Index(['Ret_MinusOne', 'Ret_2', 'Ret_3', 'Ret_4', 'Ret_5', 'Ret_6', 'Ret_7',
#        'Ret_8', 'Ret_9', 'Ret_10',
#        ...
#        'Ret_169', 'Ret_170', 'Ret_171', 'Ret_172', 'Ret_173', 'Ret_174',
#        'Ret_175', 'Ret_176', 'Ret_177', 'Ret_178'],
#       dtype='object', length=178)

# %%
returns = cols[28:206]
returns #the columns that are to be modified
# Out:
# Index(['Ret_2', 'Ret_3', 'Ret_4', 'Ret_5', 'Ret_6', 'Ret_7', 'Ret_8', 'Ret_9',
#        'Ret_10', 'Ret_11',
#        ...
#        'Ret_170', 'Ret_171', 'Ret_172', 'Ret_173', 'Ret_174', 'Ret_175',
#        'Ret_176', 'Ret_177', 'Ret_178', 'Ret_179'],
#       dtype='object', length=178)

# %%
for i in range(118):
  dataset[returns[i]] = dataset[returns[i]] +dataset[index[i]]

# %%
#modified dataset
dataset.head()
# Out:
#    Id  Feature_1  Feature_2  ...  Ret_PlusTwo  Weight_Intraday  Weight_Daily
# 0   1    3.59025  -0.117558  ...     0.028846     1.251508e+06  1.564385e+06
# 1   2    3.59025  -0.117558  ...    -0.010253     1.733950e+06  2.167438e+06
# 2   3    3.59025  -0.696727  ...     0.015711     1.529197e+06  1.911497e+06
# 3   4    3.59025  -0.694350  ...    -0.002190     1.711569e+06  2.139462e+06
# 4   5    6.00000  -1.736489  ...    -0.026552     1.267270e+06  1.584088e+06
#
# [5 rows x 211 columns]

# %%
#Splitting the dataset into X and Y, ie input and output values
X_original = dataset.iloc[:,0:27]
Y_original = dataset.iloc[:,85]

#Normalizing
normalize_X.fit(X_original)
X_scaled =normalize_X.transform(X_original)

#reshaping
X_scaled = numpy.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
model = Sequential()

model.add(LSTM(units = 10, return_sequences = True, input_shape = (X_scaled.shape[1], 1)))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10))
model.add(Dropout(0.025))

model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error' ,metrics = ['accuracy'])

# %%
model.fit(X_scaled, Y_original, epochs = 5, batch_size = 16)

X_scaled_test = numpy.reshape(X_scaled_test, (X_scaled_test.shape[0], X_scaled_test.shape[1], 1))
predicted_stock_price1 = model.predict(X_scaled_test)
# Out:
# Epoch 1/5
# 40000/40000 [==============================] - 125s 3ms/step - loss: 0.0010 - acc: 0.0000e+00
# Epoch 2/5
# 40000/40000 [==============================] - 120s 3ms/step - loss: 0.0010 - acc: 0.0000e+00
# Epoch 3/5
# 40000/40000 [==============================] - 120s 3ms/step - loss: 0.0010 - acc: 0.0000e+00
# Epoch 4/5
# 40000/40000 [==============================] - 119s 3ms/step - loss: 0.0010 - acc: 0.0000e+00
# Epoch 5/5
# 40000/40000 [==============================] - 117s 3ms/step - loss: 0.0010 - acc: 0.0000e+00

# %%
plt.plot(predicted_stock_price1)
plt.plot(Y_test)
plt.title('model loss')
plt.ylabel('Value')
plt.xlabel('Data Points')
plt.legend(['Predicted','Real'], loc='upper left')
plt.show()

# %%
rows = zip(Y_test, Ynew, predicted_stock_price, predicted_stock_price1)
import csv
with open('submission.csv',"w") as f:
  writer = csv.writer(f)
  writer.writerow(("Actual Value", "Sequential Predicted Value","LSTM Predicted Value","Relative LSTM Predicted Value"))
  for row in rows:
    writer.writerow(row)
submission = pd.read_csv('submission.csv')

# %%
submission
# Out:
#        Actual Value  ... Relative LSTM Predicted Value
# 0      3.868409e-04  ...                 [-0.00394119]
# 1     -4.494642e-04  ...                 [-0.00394368]
# 2     -8.718654e-06  ...                 [-0.00394785]
# 3     -4.872371e-04  ...                 [-0.00394695]
# 4      2.453421e-04  ...                 [-0.00395041]
# 5      5.166450e-06  ...                 [-0.00394056]
# 6      1.670945e-04  ...                 [-0.00394868]
# 7      3.951321e-04  ...                 [-0.00394853]
# 8     -1.347198e-05  ...                 [-0.00394792]
# 9      2.279946e-04  ...                 [-0.00395049]
# 10    -3.321283e-04  ...                 [-0.00394683]
# 11    -8.718654e-06  ...                 [-0.00394761]
# 12     3.206656e-06  ...                 [-0.00394552]
# 13     2.157182e-04  ...                 [-0.00395516]
# 14    -5.236790e-04  ...                 [-0.00394772]
# 15    -8.011310e-04  ...                 [-0.00394784]
# 16    -7.563621e-04  ...                  [-0.0039498]
# 17     4.318345e-04  ...                 [-0.00395185]
# 18    -2.446631e-04  ...                 [-0.00394773]
# 19     5.067784e-06  ...                 [-0.00395149]
# 20    -4.826581e-04  ...                 [-0.00394905]
# 21    -7.342845e-06  ...                 [-0.00394888]
# 22     2.344680e-04  ...                  [-0.0039519]
# 23    -1.687255e-04  ...                  [-0.0039453]
# 24     4.835313e-04  ...                 [-0.00394978]
# 25    -2.915224e-04  ...                 [-0.00394754]
# 26     2.041457e-03  ...                 [-0.00394669]
# 27     2.528381e-05  ...                 [-0.00394769]
# 28    -5.571493e-04  ...                 [-0.00394573]
# 29    -4.520281e-04  ...                 [-0.00394444]
# ...             ...  ...                           ...
# 92884  1.675093e-04  ...                 [-0.00395174]
# 92885 -8.630700e-04  ...                 [-0.00394415]
# 92886 -1.952387e-04  ...                 [-0.00394936]
# 92887 -2.557389e-05  ...                 [-0.00394879]
# 92888  3.267659e-04  ...                 [-0.00394777]
# 92889 -1.746292e-04  ...                 [-0.00394879]
# 92890  3.843958e-04  ...                 [-0.00394447]
# 92891 -5.572956e-04  ...                  [-0.0039506]
# 92892 -1.915454e-04  ...                 [-0.00394928]
# 92893  2.018131e-04  ...                 [-0.00395013]
# 92894 -4.442938e-04  ...                  [-0.0039539]
# 92895  4.118117e-04  ...                 [-0.00394583]
# 92896  1.545668e-03  ...                  [-0.0039453]
# 92897  3.799683e-04  ...                 [-0.00394492]
# 92898 -7.030320e-04  ...                 [-0.00395206]
# 92899 -9.796375e-06  ...                  [-0.0039497]
# 92900  1.670567e-05  ...                  [-0.0039483]
# 92901 -4.228592e-04  ...                 [-0.00395049]
# 92902 -1.108469e-03  ...                 [-0.00395482]
# 92903 -2.036109e-04  ...                 [-0.00395106]
# 92904  2.012495e-04  ...                 [-0.00394648]
# 92905 -4.652719e-04  ...                 [-0.00395268]
# 92906  3.513047e-04  ...                 [-0.00394885]
# 92907  6.189885e-04  ...                  [-0.0039537]
# 92908 -3.606438e-06  ...                 [-0.00394406]
# 92909  2.607337e-07  ...                 [-0.00394828]
# 92910  7.841234e-04  ...                 [-0.00394876]
# 92911  4.822604e-04  ...                 [-0.00394674]
# 92912  2.007898e-05  ...                 [-0.00394505]
# 92913  2.756751e-04  ...                 [-0.00394927]
#
# [92914 rows x 4 columns]
