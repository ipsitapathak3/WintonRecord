# %%
import numpy
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('train.csv')
dataset.fillna(dataset.mean(axis=0), inplace=True)
dataset.head()
# Out:
#    Id  Feature_1  Feature_2  ...  Ret_PlusTwo  Weight_Intraday  Weight_Daily
# 0   1    3.59025  -0.117558  ...     0.028846     1.251508e+06  1.564385e+06
# 1   2    3.59025  -0.117558  ...    -0.010253     1.733950e+06  2.167438e+06
# 2   3    3.59025  -0.696727  ...     0.015711     1.529197e+06  1.911497e+06
# 3   4    3.59025  -0.694350  ...    -0.002190     1.711569e+06  2.139462e+06
# 4   5    6.00000  -1.736489  ...    -0.026552     1.267270e+06  1.584088e+06
#
# [5 rows x 211 columns]

# %%
#Splitting the dataset into X and Y, ie input and output values
X_original = dataset.iloc[:,0:27]
Y_original = dataset.iloc[:,145]

# %%
X_original.head()
# Out:
#    Id  Feature_1  Feature_2  ...  Feature_24  Feature_25  Ret_MinusTwo
# 0   1    3.59025  -0.117558  ...   -1.209290   -0.329675      0.055275
# 1   2    3.59025  -0.117558  ...    0.953424   -0.709462      0.009748
# 2   3    3.59025  -0.696727  ...   -1.798090   -1.019370      0.003077
# 3   4    3.59025  -0.694350  ...   -1.788725   -0.329675      0.000984
# 4   5    6.00000  -1.736489  ...   -5.993092    3.219820     -0.018224
#
# [5 rows x 27 columns]

# %%
X_original.shape
# Out:
# (40000, 27)

# %%
Y_original.head()
# Out:
# 0   -0.000009
# 1   -0.000007
# 2   -0.000270
# 3    0.000153
# 4    0.001208
# Name: Ret_119, dtype: float64

# %%
Y_original.shape
# Out:
# (40000,)

# %%
#Normalizing X_original to X_scaled
normalize_X = MinMaxScaler()
normalize_X.fit(X_original)
X_scaled=normalize_X.transform(X_original)

# %%
#Model 1: Sequential
model = Sequential()
model.add(Dense(12, input_dim=27, kernel_initializer='normal'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 12)                336
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])

# %%
result = model.fit(X_scaled, Y_original,epochs=50, batch_size=10)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 40000/40000 [==============================] - 4s 97us/step - loss: 2.0983e-06 - mean_squared_error: 2.0983e-06 - mean_absolute_error: 7.3189e-04
# Epoch 2/50
# 40000/40000 [==============================] - 4s 100us/step - loss: 1.3777e-06 - mean_squared_error: 1.3777e-06 - mean_absolute_error: 6.8693e-04
# Epoch 3/50
# 40000/40000 [==============================] - 4s 99us/step - loss: 1.3754e-06 - mean_squared_error: 1.3754e-06 - mean_absolute_error: 6.9252e-04
# Epoch 4/50
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.3854e-06 - mean_squared_error: 1.3854e-06 - mean_absolute_error: 6.9326e-04
# Epoch 5/50
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.3782e-06 - mean_squared_error: 1.3782e-06 - mean_absolute_error: 6.9204e-04
# Epoch 6/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3748e-06 - mean_squared_error: 1.3748e-06 - mean_absolute_error: 6.8950e-04
# Epoch 7/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3798e-06 - mean_squared_error: 1.3798e-06 - mean_absolute_error: 6.9313e-04
# Epoch 8/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3881e-06 - mean_squared_error: 1.3881e-06 - mean_absolute_error: 6.9610e-04
# Epoch 9/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3797e-06 - mean_squared_error: 1.3797e-06 - mean_absolute_error: 6.9233e-04
# Epoch 10/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3702e-06 - mean_squared_error: 1.3702e-06 - mean_absolute_error: 6.8651e-04
# Epoch 11/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3802e-06 - mean_squared_error: 1.3802e-06 - mean_absolute_error: 6.9144e-04
# Epoch 12/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3774e-06 - mean_squared_error: 1.3774e-06 - mean_absolute_error: 6.9027e-04
# Epoch 13/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3905e-06 - mean_squared_error: 1.3905e-06 - mean_absolute_error: 6.9858e-04
# Epoch 14/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.3815e-06 - mean_squared_error: 1.3815e-06 - mean_absolute_error: 6.9310e-04
# Epoch 15/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3758e-06 - mean_squared_error: 1.3758e-06 - mean_absolute_error: 6.9000e-04
# Epoch 16/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3811e-06 - mean_squared_error: 1.3811e-06 - mean_absolute_error: 6.9488e-04
# Epoch 17/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3938e-06 - mean_squared_error: 1.3938e-06 - mean_absolute_error: 6.9807e-04
# Epoch 18/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3805e-06 - mean_squared_error: 1.3805e-06 - mean_absolute_error: 6.9333e-04
# Epoch 19/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3839e-06 - mean_squared_error: 1.3839e-06 - mean_absolute_error: 6.9320e-04
# Epoch 20/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.3858e-06 - mean_squared_error: 1.3858e-06 - mean_absolute_error: 6.9568e-04
# Epoch 21/50
# 40000/40000 [==============================] - 4s 97us/step - loss: 1.3869e-06 - mean_squared_error: 1.3869e-06 - mean_absolute_error: 6.9720e-04
# Epoch 22/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3770e-06 - mean_squared_error: 1.3770e-06 - mean_absolute_error: 6.9142e-04
# Epoch 23/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3856e-06 - mean_squared_error: 1.3856e-06 - mean_absolute_error: 6.9526e-04
# Epoch 24/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3938e-06 - mean_squared_error: 1.3938e-06 - mean_absolute_error: 7.0173e-04
# Epoch 25/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3985e-06 - mean_squared_error: 1.3985e-06 - mean_absolute_error: 7.0178e-04
# Epoch 26/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.3828e-06 - mean_squared_error: 1.3828e-06 - mean_absolute_error: 6.9463e-04
# Epoch 27/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3717e-06 - mean_squared_error: 1.3717e-06 - mean_absolute_error: 6.8410e-04
# Epoch 28/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3771e-06 - mean_squared_error: 1.3771e-06 - mean_absolute_error: 6.9170e-04
# Epoch 29/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3779e-06 - mean_squared_error: 1.3779e-06 - mean_absolute_error: 6.9171e-04
# Epoch 30/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3798e-06 - mean_squared_error: 1.3798e-06 - mean_absolute_error: 6.9169e-04
# Epoch 31/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3710e-06 - mean_squared_error: 1.3710e-06 - mean_absolute_error: 6.8578e-04
# Epoch 32/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3863e-06 - mean_squared_error: 1.3863e-06 - mean_absolute_error: 6.9943e-04
# Epoch 33/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3799e-06 - mean_squared_error: 1.3799e-06 - mean_absolute_error: 6.9431e-04
# Epoch 34/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3719e-06 - mean_squared_error: 1.3719e-06 - mean_absolute_error: 6.8772e-04
# Epoch 35/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3871e-06 - mean_squared_error: 1.3871e-06 - mean_absolute_error: 6.9603e-04
# Epoch 36/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.3724e-06 - mean_squared_error: 1.3724e-06 - mean_absolute_error: 6.9029e-04
# Epoch 37/50
# 40000/40000 [==============================] - 4s 92us/step - loss: 1.3732e-06 - mean_squared_error: 1.3732e-06 - mean_absolute_error: 6.9038e-04
# Epoch 38/50
# 40000/40000 [==============================] - 4s 91us/step - loss: 1.3800e-06 - mean_squared_error: 1.3800e-06 - mean_absolute_error: 6.9297e-04
# Epoch 39/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.3755e-06 - mean_squared_error: 1.3755e-06 - mean_absolute_error: 6.8501e-04
# Epoch 40/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.3973e-06 - mean_squared_error: 1.3973e-06 - mean_absolute_error: 7.0354e-04
# Epoch 41/50
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.3767e-06 - mean_squared_error: 1.3767e-06 - mean_absolute_error: 6.9189e-04
# Epoch 42/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3932e-06 - mean_squared_error: 1.3932e-06 - mean_absolute_error: 6.9851e-04
# Epoch 43/50
# 40000/40000 [==============================] - 4s 93us/step - loss: 1.3875e-06 - mean_squared_error: 1.3875e-06 - mean_absolute_error: 6.9879e-04
# Epoch 44/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.3823e-06 - mean_squared_error: 1.3823e-06 - mean_absolute_error: 6.9584e-04
# Epoch 45/50
# 40000/40000 [==============================] - 4s 108us/step - loss: 1.3759e-06 - mean_squared_error: 1.3759e-06 - mean_absolute_error: 6.9417e-04
# Epoch 46/50
# 40000/40000 [==============================] - 4s 104us/step - loss: 1.3885e-06 - mean_squared_error: 1.3885e-06 - mean_absolute_error: 6.9506e-04
# Epoch 47/50
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.3840e-06 - mean_squared_error: 1.3840e-06 - mean_absolute_error: 6.9314e-04
# Epoch 48/50
# 40000/40000 [==============================] - 4s 94us/step - loss: 1.3751e-06 - mean_squared_error: 1.3751e-06 - mean_absolute_error: 6.8936e-04
# Epoch 49/50
# 40000/40000 [==============================] - 4s 95us/step - loss: 1.3878e-06 - mean_squared_error: 1.3878e-06 - mean_absolute_error: 6.9435e-04
# Epoch 50/50
# 40000/40000 [==============================] - 4s 97us/step - loss: 1.3794e-06 - mean_squared_error: 1.3794e-06 - mean_absolute_error: 6.8916e-04

# %%
plt.plot(result.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
testdata = pd.read_csv('test_2.csv')
testdata.fillna(testdata.mean(axis=0), inplace=True)

# %%
#Splitting the test data and normalizing
X_test = testdata.iloc[:,0:27] 
Y_test = testdata.iloc[:,145]

normalize_X.fit(X_test)
X_scaled_test =normalize_X.transform(X_test)

# %%
Ynew = model.predict(X_scaled_test)

# %%
X_scaled_test
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 6.37679216e-01, ...,
#         7.83682410e-01, 2.48052986e-01, 4.64848302e-01],
#        [1.07627566e-05, 2.71755589e-01, 4.41862324e-01, ...,
#         7.13381825e-01, 1.99226110e-01, 4.89662857e-01],
#        [2.15255131e-05, 2.71755589e-01, 3.78082324e-01, ...,
#         6.88014797e-01, 2.66320968e-01, 4.41931083e-01],
#        ...,
#        [9.99978474e-01, 2.71755589e-01, 4.37891431e-01, ...,
#         8.29903162e-01, 2.07895939e-01, 4.88644410e-01],
#        [9.99989237e-01, 1.11111111e-01, 4.41862324e-01, ...,
#         6.89469275e-01, 8.98537291e-02, 4.83721385e-01],
#        [1.00000000e+00, 2.71755589e-01, 5.07609473e-01, ...,
#         4.98240048e-01, 1.07168052e-01, 4.48951065e-01]])

# %%
X_scaled_test.shape
# Out:
# (92914, 27)

# %%
Ynew
# Out:
# array([[0.00014391],
#        [0.00014391],
#        [0.00014391],
#        ...,
#        [0.00014391],
#        [0.00014391],
#        [0.00014391]], dtype=float32)

# %%
Ynew.shape
# Out:
# (92914, 1)

# %%
plt.plot(Ynew)
plt.plot(Y_test)
plt.title('model loss')
plt.ylabel('Value')
plt.xlabel('Data Points')
plt.legend(['Predicted','Real'], loc='upper left')
plt.show()
Ynew
# Out:
# array([[0.00014391],
#        [0.00014391],
#        [0.00014391],
#        ...,
#        [0.00014391],
#        [0.00014391],
#        [0.00014391]], dtype=float32)

# %%
#Model 2:LSTM with the original data
X_scaled = numpy.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()

model.add(LSTM(units = 10, return_sequences = True, input_shape = (X_scaled.shape[1], 1)))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10))
model.add(Dropout(0.025))

model.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error' ,metrics = ['accuracy'])

# %%
model.fit(X_scaled, Y_original, epochs = 5, batch_size = 16)

X_scaled_test = numpy.reshape(X_scaled_test, (X_scaled_test.shape[0], X_scaled_test.shape[1], 1))
predicted_stock_price = model.predict(X_scaled_test)
# Out:
# Epoch 1/5
# 40000/40000 [==============================] - 132s 3ms/step - loss: 1.3358e-06 - acc: 0.0028
# Epoch 2/5
# 40000/40000 [==============================] - 131s 3ms/step - loss: 1.3553e-06 - acc: 0.0028
# Epoch 3/5
# 40000/40000 [==============================] - 119s 3ms/step - loss: 1.3410e-06 - acc: 0.0028
# Epoch 4/5
# 40000/40000 [==============================] - 117s 3ms/step - loss: 1.3473e-06 - acc: 0.0028
# Epoch 5/5
# 40000/40000 [==============================] - 116s 3ms/step - loss: 1.3511e-06 - acc: 0.0028

# %%
plt.plot(predicted_stock_price)
plt.plot(Y_test)
plt.title('model loss')
plt.ylabel('Value')
plt.xlabel('Data Points')
plt.legend(['Predicted','Real'], loc='upper left')
plt.show()

# %%
#Model 3 uses modtified data: returns relative to day 1 instead of thr previous day

#Modifying one column:
dataframe = pd.DataFrame({"Ret_2": numpy.random.randn(898), "Ret_3": numpy.random.randn(898)}) 
dataframe['Ret_3new'] = dataframe['Ret_2'] + dataframe['Ret_3']
dataframe.head()
# Out:
#       Ret_2     Ret_3  Ret_3new
# 0  0.621708  0.281356  0.903064
# 1 -0.125547  0.021956 -0.103590
# 2 -0.208384  0.933212  0.724828
# 3 -1.079682 -0.581606 -1.661289
# 4 -1.594410  1.465256 -0.129154

# %%
cols = dataset.columns
index = cols[27:205]
index #the columns that are used TO modify
# Out:
# Index(['Ret_MinusOne', 'Ret_2', 'Ret_3', 'Ret_4', 'Ret_5', 'Ret_6', 'Ret_7',
#        'Ret_8', 'Ret_9', 'Ret_10',
#        ...
#        'Ret_169', 'Ret_170', 'Ret_171', 'Ret_172', 'Ret_173', 'Ret_174',
#        'Ret_175', 'Ret_176', 'Ret_177', 'Ret_178'],
#       dtype='object', length=178)

# %%
returns = cols[28:206]
returns #the columns that are to be modified
# Out:
# Index(['Ret_2', 'Ret_3', 'Ret_4', 'Ret_5', 'Ret_6', 'Ret_7', 'Ret_8', 'Ret_9',
#        'Ret_10', 'Ret_11',
#        ...
#        'Ret_170', 'Ret_171', 'Ret_172', 'Ret_173', 'Ret_174', 'Ret_175',
#        'Ret_176', 'Ret_177', 'Ret_178', 'Ret_179'],
#       dtype='object', length=178)

# %%
for i in range(118):
  dataset[returns[i]] = dataset[returns[i]] +dataset[index[i]]

# %%
#modified dataset
dataset.head()
# Out:
#    Id  Feature_1  Feature_2  ...  Ret_PlusTwo  Weight_Intraday  Weight_Daily
# 0   1    3.59025  -0.117558  ...     0.028846     1.251508e+06  1.564385e+06
# 1   2    3.59025  -0.117558  ...    -0.010253     1.733950e+06  2.167438e+06
# 2   3    3.59025  -0.696727  ...     0.015711     1.529197e+06  1.911497e+06
# 3   4    3.59025  -0.694350  ...    -0.002190     1.711569e+06  2.139462e+06
# 4   5    6.00000  -1.736489  ...    -0.026552     1.267270e+06  1.584088e+06
#
# [5 rows x 211 columns]

# %%
#Splitting the dataset into X and Y, ie input and output values
X_original = dataset.iloc[:,0:27]
Y_original = dataset.iloc[:,145]

#Normalizing
normalize_X.fit(X_original)
X_scaled =normalize_X.transform(X_original)

#reshaping
X_scaled = numpy.reshape(X_scaled, (X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
model = Sequential()

model.add(LSTM(units = 10, return_sequences = True, input_shape = (X_scaled.shape[1], 1)))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.025))

model.add(LSTM(units = 10))
model.add(Dropout(0.025))

model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error' ,metrics = ['accuracy'])

# %%
model.fit(X_scaled, Y_original, epochs = 5, batch_size = 16)

X_scaled_test = numpy.reshape(X_scaled_test, (X_scaled_test.shape[0], X_scaled_test.shape[1], 1))
predicted_stock_price1 = model.predict(X_scaled_test)
# Out:
# Epoch 1/5
# 40000/40000 [==============================] - 125s 3ms/step - loss: 0.0011 - acc: 0.0000e+00
# Epoch 2/5
# 40000/40000 [==============================] - 121s 3ms/step - loss: 0.0011 - acc: 0.0000e+00
# Epoch 3/5
# 40000/40000 [==============================] - 121s 3ms/step - loss: 0.0011 - acc: 0.0000e+00
# Epoch 4/5
# 40000/40000 [==============================] - 122s 3ms/step - loss: 0.0011 - acc: 0.0000e+00
# Epoch 5/5
# 40000/40000 [==============================] - 121s 3ms/step - loss: 0.0011 - acc: 0.0000e+00

# %%
plt.plot(predicted_stock_price1)
plt.plot(Y_test)
plt.title('model loss')
plt.ylabel('Value')
plt.xlabel('Data Points')
plt.legend(['Predicted','Real'], loc='upper left')
plt.show()

# %%
rows = zip(Y_test, Ynew, predicted_stock_price, predicted_stock_price1)
import csv
with open('submission.csv',"w") as f:
  writer = csv.writer(f)
  writer.writerow(("Actual Value", "Sequential Predicted Value","LSTM Predicted Value","Relative LSTM Predicted Value"))
  for row in rows:
    writer.writerow(row)
submission = pd.read_csv('submission.csv')

# %%
submission
# Out:
#        Actual Value  ... Relative LSTM Predicted Value
# 0     -5.562795e-04  ...                  [0.00377372]
# 1      4.679626e-04  ...                  [0.00372741]
# 2     -1.684510e-04  ...                  [0.00367357]
# 3      1.391717e-03  ...                  [0.00367883]
# 4      2.266626e-04  ...                  [0.00361973]
# 5     -1.074752e-03  ...                  [0.00373257]
# 6     -1.716402e-05  ...                  [0.00367299]
# 7      1.207147e-03  ...                  [0.00368042]
# 8      3.407016e-04  ...                  [0.00367931]
# 9      2.533126e-04  ...                  [0.00363553]
# 10    -2.748285e-06  ...                  [0.00365262]
# 11    -1.273914e-04  ...                  [0.00367557]
# 12     4.133545e-04  ...                  [0.00368698]
# 13     1.194380e-03  ...                  [0.00357621]
# 14     3.614001e-04  ...                  [0.00368595]
# 15     4.858101e-06  ...                  [0.00367041]
# 16    -1.860837e-04  ...                  [0.00365901]
# 17    -1.110067e-03  ...                  [0.00363861]
# 18    -1.059864e-05  ...                  [0.00368652]
# 19     3.881688e-04  ...                  [0.00362741]
# 20    -1.758428e-03  ...                  [0.00367073]
# 21     3.799955e-04  ...                  [0.00366986]
# 22     1.147782e-03  ...                  [0.00360373]
# 23     4.035599e-04  ...                  [0.00371605]
# 24    -3.358381e-06  ...                  [0.00363948]
# 25     7.535559e-04  ...                  [0.00369949]
# 26    -5.586692e-03  ...                  [0.00367372]
# 27    -2.016816e-04  ...                  [0.00366896]
# 28    -1.100459e-03  ...                   [0.0037001]
# 29     6.615328e-04  ...                  [0.00371333]
# ...             ...  ...                           ...
# 92884  5.677615e-04  ...                  [0.00363778]
# 92885  2.760881e-04  ...                  [0.00370745]
# 92886  2.489724e-06  ...                  [0.00364236]
# 92887 -1.450663e-03  ...                  [0.00368598]
# 92888  8.213348e-06  ...                  [0.00367503]
# 92889 -2.706042e-04  ...                  [0.00365594]
# 92890 -3.870541e-04  ...                  [0.00372282]
# 92891 -8.797513e-05  ...                  [0.00364096]
# 92892 -1.699917e-05  ...                  [0.00365051]
# 92893  1.548664e-05  ...                  [0.00363928]
# 92894 -3.615410e-04  ...                  [0.00362675]
# 92895 -3.623802e-05  ...                  [0.00368884]
# 92896 -6.141280e-04  ...                  [0.00369563]
# 92897  4.604692e-04  ...                  [0.00367083]
# 92898  1.648220e-07  ...                  [0.00361297]
# 92899 -4.248325e-04  ...                  [0.00367005]
# 92900  1.648220e-07  ...                  [0.00366702]
# 92901 -2.287357e-04  ...                  [0.00365171]
# 92902 -3.764460e-04  ...                  [0.00357502]
# 92903 -5.206027e-05  ...                  [0.00362875]
# 92904 -3.089371e-04  ...                  [0.00371752]
# 92905  4.942669e-04  ...                  [0.00362198]
# 92906  9.557412e-04  ...                  [0.00366727]
# 92907  6.618339e-05  ...                  [0.00358132]
# 92908  7.847136e-05  ...                  [0.00370377]
# 92909  4.732124e-04  ...                  [0.00367005]
# 92910 -1.737989e-03  ...                  [0.00368152]
# 92911  1.534965e-04  ...                   [0.0036823]
# 92912 -7.107982e-06  ...                  [0.00371089]
# 92913  5.178986e-04  ...                  [0.00368541]
#
# [92914 rows x 4 columns]
